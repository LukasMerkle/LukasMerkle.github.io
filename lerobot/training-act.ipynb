# %% [markdown]
# # 🤗 x 🦾: Training ACT with LeRobot Notebook
#
# Welcome to the **LeRobot ACT training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `ACT` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `ACT` policy for 100,000 steps typically takes **about 1.5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer.
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:03
# 🔁 Restarting kernel...

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !conda install ffmpeg=7.1.1 -c conda-forge
# !cd lerobot
# !git checkout d324ffe810d17264a0b1e628698aa1fa09aa639c
# !pip install -e .
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !wandb login
# Out:
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: merkle-lukas (merkle-lukas-carnegie-mellon-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Start training ACT with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--policy.type=act`:
#    Specifies the policy configuration to use. `act` refers to [configuration_act.py](../lerobot/common/policies/act/configuration_act.py), which will automatically adapt to your dataset’s setup (e.g., number of motors and cameras).
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this. Set to `False` if you do not plan on using Weights & Biases.

# %%
# !cd lerobot && python src/lerobot/scripts/lerobot_train.py \
  --dataset.repo_id=lmerkle/charger \
  --policy.type=act \
  --output_dir=outputs/train/hf_act_record10 \
  --job_name=hf_act_training_job \
  --policy.device=cuda \
  --wandb.enable=True \
  --policy.repo_id=lmerkle/hf_act_recordpolicy10 \
  --batch_size 64 \
  --save_freq 5000 \
  --steps 30000 \
  --optimizer.lr=5e-4 \
  --num_workers 16
# Out:
# INFO 2026-03-09 01:27:08 ot_train.py:197 {'batch_size': 64,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'lmerkle/charger',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'hf_act_training_job',
#  'log_freq': 200,
#  'num_workers': 16,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/hf_act_record10',
#  'peft': None,
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': None,
#             'private': None,
#             'push_to_hub': True,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': 'lmerkle/hf_act_recordpolicy10',
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_peft': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'rabc_epsilon': 1e-06,
#  'rabc_head_mode': 'sparse',
#  'rabc_kappa': 0.01,
#  'rabc_progress_path': None,
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 5000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 30000,
#  'tolerance_s': 0.0001,
#  'use_policy_training_preset': True,
#  'use_rabc': False,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2026-03-09 01:27:09 db_utils.py:117 Logs will be synced with wandb.
# INFO 2026-03-09 01:27:09 db_utils.py:118 Track this run --> https://wandb.ai/merkle-lukas-carnegie-mellon-university/lerobot/runs/6727t4wu
# INFO 2026-03-09 01:27:09 ot_train.py:217 Creating dataset
# INFO 2026-03-09 01:27:09 eo_utils.py:106 Using video codec: libsvtav1
# INFO 2026-03-09 01:27:09 ot_train.py:235 Creating policy
# INFO 2026-03-09 01:27:10 ot_train.py:290 Creating optimizer and scheduler
# INFO 2026-03-09 01:27:10 ot_train.py:325 Output dir: outputs/train/hf_act_record10
# INFO 2026-03-09 01:27:10 ot_train.py:332 cfg.steps=30000 (30K)
# INFO 2026-03-09 01:27:10 ot_train.py:333 dataset.num_frames=25965 (26K)
# INFO 2026-03-09 01:27:10 ot_train.py:334 dataset.num_episodes=51
# INFO 2026-03-09 01:27:10 ot_train.py:337 Effective batch size: 64 x 1 = 64
# INFO 2026-03-09 01:27:10 ot_train.py:338 num_learnable_params=51597190 (52M)
# INFO 2026-03-09 01:27:10 ot_train.py:339 num_total_params=51597190 (52M)
# Training:   0% 0/30000 [00:00<?, ?step/s]INFO 2026-03-09 01:27:10 ot_train.py:403 Start offline training on a fixed dataset, with effective batch size: 64
# Training:   1% 200/30000 [00:36<1:21:30,  6.09step/s]INFO 2026-03-09 01:27:46 ot_train.py:435 step:200 smpl:13K ep:25 epch:0.49 loss:5.504 grdn:75.851 lr:1.0e-05 updt_s:0.170 data_s:0.013
# Training:   1% 400/30000 [01:09<1:19:37,  6.20step/s]INFO 2026-03-09 01:28:19 ot_train.py:435 step:400 smpl:26K ep:50 epch:0.99 loss:2.160 grdn:34.589 lr:1.0e-05 updt_s:0.158 data_s:0.005
# Training:   2% 600/30000 [01:44<1:22:49,  5.92step/s]INFO 2026-03-09 01:28:54 ot_train.py:435 step:600 smpl:38K ep:75 epch:1.48 loss:1.686 grdn:31.799 lr:1.0e-05 updt_s:0.165 data_s:0.010
# Training:   3% 800/30000 [02:17<1:18:49,  6.17step/s]INFO 2026-03-09 01:29:27 ot_train.py:435 step:800 smpl:51K ep:101 epch:1.97 loss:1.364 grdn:28.172 lr:1.0e-05 updt_s:0.160 data_s:0.005
# Training:   3% 1000/30000 [02:52<1:18:59,  6.12step/s]INFO 2026-03-09 01:30:02 ot_train.py:435 step:1K smpl:64K ep:126 epch:2.46 loss:1.096 grdn:25.348 lr:1.0e-05 updt_s:0.161 data_s:0.012
# Training:   4% 1200/30000 [03:25<1:17:44,  6.17step/s]INFO 2026-03-09 01:30:35 ot_train.py:435 step:1K smpl:77K ep:151 epch:2.96 loss:0.893 grdn:23.873 lr:1.0e-05 updt_s:0.161 data_s:0.005
# Training:   5% 1400/30000 [04:00<1:20:58,  5.89step/s]INFO 2026-03-09 01:31:10 ot_train.py:435 step:1K smpl:90K ep:176 epch:3.45 loss:0.729 grdn:21.508 lr:1.0e-05 updt_s:0.160 data_s:0.012
# Training:   5% 1600/30000 [04:33<1:16:33,  6.18step/s]INFO 2026-03-09 01:31:43 ot_train.py:435 step:2K smpl:102K ep:201 epch:3.94 loss:0.603 grdn:19.474 lr:1.0e-05 updt_s:0.161 data_s:0.005
# Training:   6% 1800/30000 [05:07<1:16:52,  6.11step/s]INFO 2026-03-09 01:32:17 ot_train.py:435 step:2K smpl:115K ep:226 epch:4.44 loss:0.504 grdn:18.068 lr:1.0e-05 updt_s:0.158 data_s:0.013
# Training:   7% 2000/30000 [05:40<1:15:47,  6.16step/s]INFO 2026-03-09 01:32:50 ot_train.py:435 step:2K smpl:128K ep:251 epch:4.93 loss:0.430 grdn:16.457 lr:1.0e-05 updt_s:0.158 data_s:0.005
# Training:   7% 2200/30000 [06:15<1:15:51,  6.11step/s]INFO 2026-03-09 01:33:25 ot_train.py:435 step:2K smpl:141K ep:277 epch:5.42 loss:0.372 grdn:15.994 lr:1.0e-05 updt_s:0.161 data_s:0.012
# Training:   8% 2400/30000 [06:48<1:16:48,  5.99step/s]INFO 2026-03-09 01:33:58 ot_train.py:435 step:2K smpl:154K ep:302 epch:5.92 loss:0.334 grdn:14.960 lr:1.0e-05 updt_s:0.161 data_s:0.005
# Training:   9% 2600/30000 [07:22<1:14:24,  6.14step/s]INFO 2026-03-09 01:34:32 ot_train.py:435 step:3K smpl:166K ep:327 epch:6.41 loss:0.300 grdn:13.744 lr:1.0e-05 updt_s:0.159 data_s:0.011
# Training:   9% 2800/30000 [07:55<1:13:47,  6.14step/s]INFO 2026-03-09 01:35:05 ot_train.py:435 step:3K smpl:179K ep:352 epch:6.90 loss:0.276 grdn:13.231 lr:1.0e-05 updt_s:0.158 data_s:0.005
# Training:  10% 3000/30000 [08:29<1:13:16,  6.14step/s]INFO 2026-03-09 01:35:39 ot_train.py:435 step:3K smpl:192K ep:377 epch:7.39 loss:0.256 grdn:13.327 lr:1.0e-05 updt_s:0.158 data_s:0.011
# Training:  11% 3200/30000 [09:02<1:12:53,  6.13step/s]INFO 2026-03-09 01:36:12 ot_train.py:435 step:3K smpl:205K ep:402 epch:7.89 loss:0.240 grdn:12.755 lr:1.0e-05 updt_s:0.158 data_s:0.005
# Training:  11% 3400/30000 [09:36<1:15:39,  5.86step/s]INFO 2026-03-09 01:36:46 ot_train.py:435 step:3K smpl:218K ep:427 epch:8.38 loss:0.226 grdn:12.400 lr:1.0e-05 updt_s:0.160 data_s:0.012
# Training:  12% 3600/30000 [10:09<1:12:02,  6.11step/s]INFO 2026-03-09 01:37:19 ot_train.py:435 step:4K smpl:230K ep:453 epch:8.87 loss:0.216 grdn:11.625 lr:1.0e-05 updt_s:0.161 data_s:0.005
# Training:  13% 3800/30000 [10:43<1:13:47,  5.92step/s]INFO 2026-03-09 01:37:53 ot_train.py:435 step:4K smpl:243K ep:478 epch:9.37 loss:0.205 grdn:11.728 lr:1.0e-05 updt_s:0.159 data_s:0.011
# Training:  13% 4000/30000 [11:16<1:10:56,  6.11step/s]INFO 2026-03-09 01:38:26 ot_train.py:435 step:4K smpl:256K ep:503 epch:9.86 loss:0.196 grdn:11.007 lr:1.0e-05 updt_s:0.160 data_s:0.005
# Training:  14% 4200/30000 [11:51<1:09:56,  6.15step/s]INFO 2026-03-09 01:39:01 ot_train.py:435 step:4K smpl:269K ep:528 epch:10.35 loss:0.187 grdn:10.407 lr:1.0e-05 updt_s:0.160 data_s:0.012
# Training:  15% 4400/30000 [12:24<1:11:31,  5.97step/s]INFO 2026-03-09 01:39:34 ot_train.py:435 step:4K smpl:282K ep:553 epch:10.85 loss:0.181 grdn:10.159 lr:1.0e-05 updt_s:0.160 data_s:0.005
# Training:  15% 4600/30000 [12:58<1:10:23,  6.01step/s]INFO 2026-03-09 01:40:09 ot_train.py:435 step:5K smpl:294K ep:578 epch:11.34 loss:0.174 grdn:10.359 lr:1.0e-05 updt_s:0.160 data_s:0.013
# Training:  16% 4800/30000 [13:31<1:11:43,  5.86step/s]INFO 2026-03-09 01:40:41 ot_train.py:435 step:5K smpl:307K ep:603 epch:11.83 loss:0.169 grdn:9.776 lr:1.0e-05 updt_s:0.159 data_s:0.005
# Training:  17% 5000/30000 [14:05<1:08:21,  6.10step/s]INFO 2026-03-09 01:41:15 ot_train.py:435 step:5K smpl:320K ep:629 epch:12.32 loss:0.163 grdn:9.589 lr:1.0e-05 updt_s:0.159 data_s:0.011
# INFO 2026-03-09 01:41:15 ot_train.py:455 Checkpoint policy after step 5000
# Training:  17% 5200/30000 [14:40<1:08:07,  6.07step/s]INFO 2026-03-09 01:41:50 ot_train.py:435 step:5K smpl:333K ep:654 epch:12.82 loss:0.158 grdn:9.424 lr:1.0e-05 updt_s:0.161 data_s:0.005
# Training:  18% 5400/30000 [15:14<1:06:37,  6.15step/s]INFO 2026-03-09 01:42:24 ot_train.py:435 step:5K smpl:346K ep:679 epch:13.31 loss:0.155 grdn:9.906 lr:1.0e-05 updt_s:0.158 data_s:0.012
# Training:  19% 5600/30000 [15:47<1:06:19,  6.13step/s]INFO 2026-03-09 01:42:57 ot_train.py:435 step:6K smpl:358K ep:704 epch:13.80 loss:0.151 grdn:9.133 lr:1.0e-05 updt_s:0.158 data_s:0.005
# Training:  19% 5800/30000 [16:21<1:05:46,  6.13step/s]INFO 2026-03-09 01:43:31 ot_train.py:435 step:6K smpl:371K ep:729 epch:14.30 loss:0.146 grdn:9.049 lr:1.0e-05 updt_s:0.158 data_s:0.011
# Training:  20% 6000/30000 [16:53<1:05:11,  6.14step/s]INFO 2026-03-09 01:44:03 ot_train.py:435 step:6K smpl:384K ep:754 epch:14.79 loss:0.144 grdn:8.981 lr:1.0e-05 updt_s:0.158 data_s:0.005
# Training:
lr:1.0e-05 updt_s:0.158 data_s:0.005
# Training:  30% 9000/30000 [25:12<57:03,  6.13step/s]INFO 2026-03-09 01:52:22 ot_train.py:435 step:9K smpl:576K ep:1K epch:22.18 loss:0.109 grdn:7.867 lr:1.0e-05 updt_s:0.157 data_s:0.011
# Training:  31% 9200/30000 [25:45<56:26,  6.14step/s]INFO 2026-03-09 01:52:55 ot_train.py:435 step:9K smpl:589K ep:1K epch:22.68 loss:0.106 grdn:6.692 lr:1.0e-05 updt_s:0.158 data_s:0.005
# Training:  31% 9400/30000 [26:19<55:54,  6.14step/s]INFO 2026-03-09 01:53:29 ot_train.py:435 step:9K smpl:602K ep:1K epch:23.17 loss:0.105 grdn:6.954 lr:1.0e-05 updt_s:0.158 data_s:0.011
# Training:  32% 9600/30000 [26:51<55:08,  6.17step/s]INFO 2026-03-09 01:54:02 ot_train.py:435 step:10K smpl:614K ep:1K epch:23.66 loss:0.104 grdn:6.940 lr:1.0e-05 updt_s:0.157 data_s:0.005
# Training:  33% 9800/30000 [27:25<54:51,  6.14step/s]INFO 2026-03-09 01:54:35 ot_train.py:435 step:10K smpl:627K ep:1K epch:24.16 loss:0.103 grdn:7.334 lr:1.0e-05 updt_s:0.158 data_s:0.011
# Training:  33% 10000/30000 [27:58<54:14,  6.15step/s]INFO 2026-03-09 01:55:08 ot_train.py:435 step:10K smpl:640K ep:1K epch:24.65 loss:0.101 grdn:6.646 lr:1.0e-05 updt_s:0.157 data_s:0.005
# INFO 2026-03-09 01:55:08 ot_train.py:455 Checkpoint policy after step 10000
# Training:  34% 10200/30000 [28:33<54:49,  6.02step/s]INFO 2026-03-09 01:55:43 ot_train.py:435 step:10K smpl:653K ep:1K epch:25.14 loss:0.100 grdn:6.719 lr:1.0e-05 updt_s:0.159 data_s:0.011
# Training:  35% 10400/30000 [29:06<55:12,  5.92step/s]INFO 2026-03-09 01:56:16 ot_train.py:435 step:10K smpl:666K ep:1K epch:25.63 loss:0.098 grdn:6.543 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  35% 10600/30000 [29:41<54:42,  5.91step/s]INFO 2026-03-09 01:56:51 ot_train.py:435 step:11K smpl:678K ep:1K epch:26.13 loss:0.097 grdn:6.405 lr:1.0e-05 updt_s:0.162 data_s:0.011
# Training:  36% 10800/30000 [30:15<54:42,  5.85step/s]INFO 2026-03-09 01:57:25 ot_train.py:435 step:11K smpl:691K ep:1K epch:26.62 loss:0.096 grdn:6.212 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  37% 11000/30000 [30:49<54:02,  5.86step/s]INFO 2026-03-09 01:58:00 ot_train.py:435 step:11K smpl:704K ep:1K epch:27.11 loss:0.095 grdn:6.382 lr:1.0e-05 updt_s:0.162 data_s:0.012
# Training:  37% 11200/30000 [31:23<52:37,  5.95step/s]INFO 2026-03-09 01:58:33 ot_train.py:435 step:11K smpl:717K ep:1K epch:27.61 loss:0.093 grdn:6.089 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  38% 11400/30000 [31:58<52:10,  5.94step/s]INFO 2026-03-09 01:59:08 ot_train.py:435 step:11K smpl:730K ep:1K epch:28.10 loss:0.094 grdn:6.765 lr:1.0e-05 updt_s:0.162 data_s:0.012
# Training:
lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  60% 18000/30000 [50:46<34:03,  5.87step/s]INFO 2026-03-09 02:17:56 ot_train.py:435 step:18K smpl:1M ep:2K epch:44.37 loss:0.072 grdn:5.310 lr:1.0e-05 updt_s:0.163 data_s:0.011
# Training:  61% 18200/30000 [51:20<33:13,  5.92step/s]INFO 2026-03-09 02:18:30 ot_train.py:435 step:18K smpl:1M ep:2K epch:44.86 loss:0.071 grdn:4.816 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  61% 18400/30000 [51:55<33:06,  5.84step/s]INFO 2026-03-09 02:19:05 ot_train.py:435 step:18K smpl:1M ep:2K epch:45.35 loss:0.070 grdn:4.778 lr:1.0e-05 updt_s:0.162 data_s:0.012
# Training:  62% 18600/30000 [52:28<32:08,  5.91step/s]INFO 2026-03-09 02:19:38 ot_train.py:435 step:19K smpl:1M ep:2K epch:45.85 loss:0.071 grdn:4.854 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  63% 18800/30000 [53:03<31:14,  5.97step/s]INFO 2026-03-09 02:20:13 ot_train.py:435 step:19K smpl:1M ep:2K epch:46.34 loss:0.070 grdn:5.054 lr:1.0e-05 updt_s:0.161 data_s:0.011
# Training:  63% 19000/30000 [53:36<30:48,  5.95step/s]INFO 2026-03-09 02:20:46 ot_train.py:435 step:19K smpl:1M ep:2K epch:46.83 loss:0.070 grdn:4.710 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  64% 19200/30000 [54:11<30:41,  5.86step/s]INFO 2026-03-09 02:21:21 ot_train.py:435 step:19K smpl:1M ep:2K epch:47.33 loss:0.070 grdn:5.190 lr:1.0e-05 updt_s:0.163 data_s:0.011
# Training:  65% 19400/30000 [54:45<30:09,  5.86step/s]INFO 2026-03-09 02:21:55 ot_train.py:435 step:19K smpl:1M ep:2K epch:47.82 loss:0.070 grdn:5.139 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  65% 19600/30000 [55:20<28:55,  5.99step/s]INFO 2026-03-09 02:22:30 ot_train.py:435 step:20K smpl:1M ep:2K epch:48.31 loss:0.068 grdn:4.807 lr:1.0e-05 updt_s:0.161 data_s:0.012
# Training:  66% 19800/30000 [55:53<28:21,  6.00step/s]INFO 2026-03-09 02:23:03 ot_train.py:435 step:20K smpl:1M ep:2K epch:48.80 loss:0.068 grdn:4.690 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  67% 20000/30000 [56:27<27:59,  5.96step/s]INFO 2026-03-09 02:23:38 ot_train.py:435 step:20K smpl:1M ep:3K epch:49.30 loss:0.068 grdn:4.601 lr:1.0e-05 updt_s:0.161 data_s:0.011
# INFO 2026-03-09 02:23:38 ot_train.py:455 Checkpoint policy after step 20000
# Training:  67% 20200/30000 [57:02<27:27,  5.95step/s]INFO 2026-03-09 02:24:12 ot_train.py:435 step:20K smpl:1M ep:3K epch:49.79 loss:0.068 grdn:4.921 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  68% 20400/30000 [57:37<26:52,  5.95step/s]INFO 2026-03-09 02:24:47 ot_train.py:435 step:20K smpl:1M ep:3K epch:50.28 loss:0.067 grdn:4.697 lr:1.0e-05 updt_s:0.162 data_s:0.012
# Training:  69% 20600/30000 [58:10<25:56,  6.04step/s]INFO 2026-03-09 02:25:21 ot_train.py:435 step:21K smpl:1M ep:3K epch:50.78 loss:0.067 grdn:4.896 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:
lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  80% 24000/30000 [1:07:51<16:43,  5.98step/s]INFO 2026-03-09 02:35:01 ot_train.py:435 step:24K smpl:2M ep:3K epch:59.16 loss:0.062 grdn:4.268 lr:1.0e-05 updt_s:0.162 data_s:0.013
# Training:  81% 24200/30000 [1:08:25<16:11,  5.97step/s]INFO 2026-03-09 02:35:35 ot_train.py:435 step:24K smpl:2M ep:3K epch:59.65 loss:0.061 grdn:4.131 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  81% 24400/30000 [1:09:00<15:18,  6.10step/s]INFO 2026-03-09 02:36:10 ot_train.py:435 step:24K smpl:2M ep:3K epch:60.14 loss:0.062 grdn:4.820 lr:1.0e-05 updt_s:0.161 data_s:0.011
# Training:  82% 24600/30000 [1:09:33<15:12,  5.92step/s]INFO 2026-03-09 02:36:43 ot_train.py:435 step:25K smpl:2M ep:3K epch:60.64 loss:0.061 grdn:4.373 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  83% 24800/30000 [1:10:08<14:33,  5.95step/s]INFO 2026-03-09 02:37:18 ot_train.py:435 step:25K smpl:2M ep:3K epch:61.13 loss:0.060 grdn:4.122 lr:1.0e-05 updt_s:0.161 data_s:0.010
# Training:  83% 25000/30000 [1:10:41<14:08,  5.89step/s]INFO 2026-03-09 02:37:51 ot_train.py:435 step:25K smpl:2M ep:3K epch:61.62 loss:0.060 grdn:3.997 lr:1.0e-05 updt_s:0.163 data_s:0.005
# INFO 2026-03-09 02:37:51 ot_train.py:455 Checkpoint policy after step 25000
# Training:  84% 25200/30000 [1:11:17<13:06,  6.11step/s]INFO 2026-03-09 02:38:27 ot_train.py:435 step:25K smpl:2M ep:3K epch:62.11 loss:0.061 grdn:4.463 lr:1.0e-05 updt_s:0.161 data_s:0.013
# Training:  85% 25400/30000 [1:11:51<12:48,  5.99step/s]INFO 2026-03-09 02:39:01 ot_train.py:435 step:25K smpl:2M ep:3K epch:62.61 loss:0.060 grdn:4.498 lr:1.0e-05 updt_s:0.164 data_s:0.005
# Training:  85% 25600/30000 [1:12:26<12:38,  5.80step/s]INFO 2026-03-09 02:39:36 ot_train.py:435 step:26K smpl:2M ep:3K epch:63.10 loss:0.061 grdn:4.375 lr:1.0e-05 updt_s:0.162 data_s:0.011
# Training:  86% 25800/30000 [1:12:59<11:26,  6.12step/s]INFO 2026-03-09 02:40:09 ot_train.py:435 step:26K smpl:2M ep:3K epch:63.59 loss:0.059 grdn:4.204 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  87% 26000/30000 [1:13:34<11:22,  5.86step/s]INFO 2026-03-09 02:40:44 ot_train.py:435 step:26K smpl:2M ep:3K epch:64.09 loss:0.059 grdn:4.114 lr:1.0e-05 updt_s:0.161 data_s:0.010
# Training:  87% 26200/30000 [1:14:07<10:43,  5.91step/s]INFO 2026-03-09 02:41:17 ot_train.py:435 step:26K smpl:2M ep:3K epch:64.58 loss:0.059 grdn:4.476 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  88% 26400/30000 [1:14:42<11:22,  5.27step/s]INFO 2026-03-09 02:41:52 ot_train.py:435 step:26K smpl:2M ep:3K epch:65.07 loss:0.059 grdn:4.592 lr:1.0e-05 updt_s:0.162 data_s:0.012
# Training:  89% 26600/30000 [1:15:16<09:23,  6.03step/s]INFO 2026-03-09 02:42:26 ot_train.py:435 step:27K smpl:2M ep:3K epch:65.57 loss:0.059 grdn:4.676 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  89% 26800/30000 [1:15:51<16:48,  3.17step/s]INFO 2026-03-09 02:43:01 ot_train.py:435 step:27K smpl:2M ep:3K epch:66.06 loss:0.059 grdn:4.690 lr:1.0e-05 updt_s:0.162 data_s:0.012
# Training:  90% 27000/30000 [1:16:24<08:24,  5.95step/s]INFO 2026-03-09 02:43:35 ot_train.py:435 step:27K smpl:2M ep:3K epch:66.55 loss:0.058 grdn:4.264 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  91% 27200/30000 [1:16:58<07:32,  6.19step/s]INFO 2026-03-09 02:44:08 ot_train.py:435 step:27K smpl:2M ep:3K epch:67.04 loss:0.059 grdn:4.590 lr:1.0e-05 updt_s:0.161 data_s:0.005
# Training:  91% 27400/30000 [1:17:33<07:19,  5.91step/s]INFO 2026-03-09 02:44:43 ot_train.py:435 step:27K smpl:2M ep:3K epch:67.54 loss:0.058 grdn:4.217 lr:1.0e-05 updt_s:0.162 data_s:0.012
# Training:  92% 27600/30000 [1:18:06<06:28,  6.17step/s]INFO 2026-03-09 02:45:16 ot_train.py:435 step:28K smpl:2M ep:3K epch:68.03 loss:0.057 grdn:4.029 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  93% 27800/30000 [1:18:41<06:11,  5.92step/s]INFO 2026-03-09 02:45:52 ot_train.py:435 step:28K smpl:2M ep:3K epch:68.52 loss:0.058 grdn:4.539 lr:1.0e-05 updt_s:0.163 data_s:0.013
# Training:  93% 28000/30000 [1:19:15<05:23,  6.18step/s]INFO 2026-03-09 02:46:25 ot_train.py:435 step:28K smpl:2M ep:4K epch:69.02 loss:0.057 grdn:3.937 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  94% 28200/30000 [1:19:50<05:04,  5.92step/s]INFO 2026-03-09 02:47:00 ot_train.py:435 step:28K smpl:2M ep:4K epch:69.51 loss:0.057 grdn:4.102 lr:1.0e-05 updt_s:0.162 data_s:0.012
# Training:  95% 28400/30000 [1:20:23<04:18,  6.18step/s]INFO 2026-03-09 02:47:33 ot_train.py:435 step:28K smpl:2M ep:4K epch:70.00 loss:0.057 grdn:4.095 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  95% 28600/30000 [1:20:58<03:54,  5.96step/s]INFO 2026-03-09 02:48:08 ot_train.py:435 step:29K smpl:2M ep:4K epch:70.49 loss:0.056 grdn:3.885 lr:1.0e-05 updt_s:0.162 data_s:0.011
# Training:  96% 28800/30000 [1:21:32<03:14,  6.17step/s]INFO 2026-03-09 02:48:42 ot_train.py:435 step:29K smpl:2M ep:4K epch:70.99 loss:0.056 grdn:4.065 lr:1.0e-05 updt_s:0.162 data_s:0.005
# Training:  97% 29000/30000 [1:22:06<02:47,  5.96step/s]INFO 2026-03-09 02:49:17 ot_train.py:435 step:29K smpl:2M ep:4K epch:71.48 loss:0.056 grdn:4.072 lr:1.0e-05 updt_s:0.163 data_s:0.011
# Training:  97% 29200/30000 [1:22:40<02:13,  6.01step/s]INFO 2026-03-09 02:49:50 ot_train.py:435 step:29K smpl:2M ep:4K epch:71.97 loss:0.056 grdn:4.143 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  98% 29400/30000 [1:23:15<01:39,  6.01step/s]INFO 2026-03-09 02:50:25 ot_train.py:435 step:29K smpl:2M ep:4K epch:72.47 loss:0.055 grdn:3.831 lr:1.0e-05 updt_s:0.162 data_s:0.012
# Training:  99% 29600/30000 [1:23:49<01:07,  5.91step/s]INFO 2026-03-09 02:50:59 ot_train.py:435 step:30K smpl:2M ep:4K epch:72.96 loss:0.056 grdn:4.119 lr:1.0e-05 updt_s:0.163 data_s:0.005
# Training:  99% 29800/30000 [1:24:23<00:33,  5.95step/s]INFO 2026-03-09 02:51:33 ot_train.py:435 step:30K smpl:2M ep:4K epch:73.45 loss:0.055 grdn:3.942 lr:1.0e-05 updt_s:0.161 data_s:0.010
# Training: 100% 30000/30000 [1:24:57<00:00,  6.05step/s]INFO 2026-03-09 02:52:07 ot_train.py:435 step:30K smpl:2M ep:4K epch:73.95 loss:0.056 grdn:4.291 lr:1.0e-05 updt_s:0.163 data_s:0.005
# INFO 2026-03-09 02:52:07 ot_train.py:455 Checkpoint policy after step 30000
# Training: 100% 30000/30000 [1:24:58<00:00,  5.88step/s]
# INFO 2026-03-09 02:52:08 ot_train.py:529 End of training
# INFO 2026-03-09 02:52:08 _client.py:1025 HTTP Request: POST https://huggingface.co/api/repos/create "HTTP/1.1 200 OK"
# INFO 2026-03-09 02:52:08 _client.py:1025 HTTP Request: POST https://huggingface.co/api/validate-yaml "HTTP/1.1 200 OK"
# INFO 2026-03-09 02:52:08 _client.py:1025 HTTP Request: POST https://huggingface.co/api/validate-yaml "HTTP/1.1 200 OK"
# INFO 2026-03-09 02:52:08 _client.py:1025 HTTP Request: POST https://huggingface.co/api/validate-yaml "HTTP/1.1 200 OK"
# INFO 2026-03-09 02:52:09 _client.py:1025 HTTP Request: POST https://huggingface.co/api/models/lmerkle/hf_act_recordpolicy10/preupload/main "HTTP/1.1 200 OK"
# INFO 2026-03-09 02:52:09 _client.py:1025 HTTP Request: POST https://huggingface.co/lmerkle/hf_act_recordpolicy10.git/info/lfs/objects/batch "HTTP/1.1 200 OK"
# INFO 2026-03-09 02:52:09 _client.py:1025 HTTP Request: GET https://huggingface.co/api/models/lmerkle/hf_act_recordpolicy10/xet-write-token/main "HTTP/1.1 200 OK"
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...olicy10/model.safetensors:   0% 782k/207M [00:00<?, ?B/s]
#
# Processing Files (0 / 1)      :   0% 782k/207M [00:00<02:39, 1.29MB/s, 1.96MB/s  ]
#
# Processing Files (0 / 1)      :   1% 1.34M/207M [00:00<01:55, 1.78MB/s, 2.24MB/s  ]
# New Data Upload               :   1% 563k/67.0M [00:00<01:35, 698kB/s,  939kB/s  ]
#
# Processing Files (0 / 1)      :   3% 5.28M/207M [00:01<00:27, 7.40MB/s, 6.61MB/s  ]
# New Data Upload               :   3% 4.50M/134M [00:01<00:22, 5.67MB/s, 5.63MB/s  ]
#
# Processing Files (0 / 1)      :   5% 9.79M/207M [00:01<00:16, 12.1MB/s, 9.79MB/s  ]
# New Data Upload               :   7% 9.00M/134M [00:01<00:12, 10.2MB/s, 9.01MB/s  ]
#
# Processing Files (0 / 1)      :   9% 17.7M/207M [00:01<00:09, 20.4MB/s, 14.7MB/s  ]
# New Data Upload               :  13% 16.9M/134M [00:01<00:06, 18.4MB/s, 14.1MB/s  ]
#
# Processing Files (0 / 1)      :  13% 26.7M/207M [00:01<00:06, 28.0MB/s, 19.1MB/s  ]
# New Data Upload               :  19% 25.9M/134M [00:01<00:04, 26.0MB/s, 18.5MB/s  ]
#
# Processing Files (0 / 1)      :  18% 36.2M/207M [00:01<00:05, 34.0MB/s, 22.7MB/s  ]
# New Data Upload               :  26% 35.5M/134M [00:01<00:03, 32.3MB/s, 22.2MB/s  ]
#
# Processing Files (0 / 1)      :  22% 45.2M/207M [00:02<00:04, 37.3MB/s, 25.1MB/s  ]
# New Data Upload               :  33% 44.5M/134M [00:02<00:02, 36.1MB/s, 24.7MB/s  ]
#
# Processing Files (0 / 1)      :  26% 53.1M/207M [00:02<00:04, 37.9MB/s, 26.6MB/s  ]
# New Data Upload               :  39% 52.3M/134M [00:02<00:02, 37.0MB/s, 26.2MB/s  ]
#
# Processing Files (0 / 1)      :  30% 62.1M/207M [00:02<00:03, 40.1MB/s, 28.2MB/s  ]
# New Data Upload               :  46% 61.3M/134M [00:02<00:01, 39.4MB/s, 27.9MB/s  ]
#
# Processing Files (0 / 1)      :  33% 67.8M/207M [00:02<00:03, 36.5MB/s, 28.2MB/s  ]
# New Data Upload               :  50% 67.0M/134M [00:02<00:01, 36.0MB/s, 27.9MB/s  ]
#
#   ...olicy10/model.safetensors:  33% 67.8M/207M [00:02<00:04, 30.4MB/s]
#
#   ...olicy10/model.safetensors:  33% 67.8M/207M [00:02<00:04, 27.9MB/s]
#
#   ...olicy10/model.safetensors:  33% 67.8M/207M [00:02<00:05, 25.8MB/s]
#
# Processing Files (0 / 1)      :  33% 67.8M/207M [00:03<00:10, 13.5MB/s, 21.2MB/s  ]
# New Data Upload               :  50% 67.0M/134M [00:03<00:05, 13.4MB/s, 20.9MB/s  ]
#
# Processing Files (0 / 1)      :  33% 68.4M/207M [00:03<00:12, 11.5MB/s, 20.1MB/s  ]
# New Data Upload               :  34% 67.6M/201M [00:03<00:11, 11.4MB/s, 19.9MB/s  ]
#
# Processing Files (0 / 1)      :  37% 76.2M/207M [00:03<00:07, 17.3MB/s, 21.2MB/s  ]
# New Data Upload               :  37% 75.4M/206M [00:03<00:07, 17.2MB/s, 20.9MB/s  ]
#
# Processing Files (0 / 1)      :  44% 90.7M/207M [00:04<00:03, 29.9MB/s, 23.9MB/s  ]
# New Data Upload               :  44% 89.9M/206M [00:04<00:03, 29.8MB/s, 23.7MB/s  ]
#
# Processing Files (0 / 1)      :  54% 111M/207M [00:04<00:02, 47.3MB/s, 27.7MB/s  ]
# New Data Upload               :  53% 110M/206M [00:04<00:02, 47.2MB/s, 27.5MB/s  ]
#
# Processing Files (0 / 1)      :  65% 134M/207M [00:04<00:01, 65.6MB/s, 32.0MB/s  ]
# New Data Upload               :  65% 133M/206M [00:04<00:01, 65.5MB/s, 31.8MB/s  ]
#
# Processing Files (0 / 1)      :  74% 153M/207M [00:04<00:00, 73.0MB/s, 34.7MB/s  ]
# New Data Upload               :  74% 152M/206M [00:04<00:00, 72.9MB/s, 34.5MB/s  ]
#
# Processing Files (0 / 1)      :  83% 172M/207M [00:04<00:00, 79.9MB/s, 37.5MB/s  ]
# New Data Upload               :  83% 172M/206M [00:04<00:00, 79.8MB/s, 37.3MB/s  ]
#
# Processing Files (0 / 1)      :  93% 191M/207M [00:05<00:00, 84.1MB/s, 39.9MB/s  ]
# New Data Upload               :  93% 190M/206M [00:05<00:00, 84.0MB/s, 39.7MB/s  ]
#
# Processing Files (0 / 1)      : 100% 206M/207M [00:05<00:00, 81.6MB/s, 41.3MB/s  ]
# New Data Upload               : 100% 206M/206M [00:05<00:00, 81.5MB/s, 41.1MB/s  ]
#
#   ...olicy10/model.safetensors: 100% 206M/207M [00:04<00:00, 42.8MB/s]
#
#   ...olicy10/model.safetensors: 100% 206M/207M [00:04<00:00, 41.1MB/s]
#
#   ...olicy10/model.safetensors: 100% 206M/207M [00:05<00:00, 39.5MB/s]
#
# Processing Files (1 / 1)      : 100% 207M/207M [00:06<00:00, 31.0MB/s, 35.6MB/s  ]
# New Data Upload               : 100% 206M/206M [00:06<00:00, 31.0MB/s, 35.5MB/s  ]
#
#   ...olicy10/model.safetensors: 100% 207M/207M [00:05<00:00, 36.8MB/s]
#
#   ...olicy10/model.safetensors: 100% 207M/207M [00:05<00:00, 36.0MB/s]
#
# Processing Files (1 / 1)      : 100% 207M/207M [00:06<00:00, 32.3MB/s, 33.3MB/s  ]
# New Data Upload               : 100% 206M/206M [00:06<00:00, 32.1MB/s, 33.2MB/s  ]
#   ...olicy10/model.safetensors: 100% 207M/207M [00:05<00:00, 35.5MB/s]
# INFO 2026-03-09 02:52:16 _client.py:1025 HTTP Request: POST https://huggingface.co/api/models/lmerkle/hf_act_recordpolicy10/commit/main "HTTP/1.1 200 OK"
# INFO 2026-03-09 02:52:16 etrained.py:246 Model pushed to https://huggingface.co/lmerkle/hf_act_recordpolicy10
# INFO 2026-03-09 02:52:16 _client.py:1025 HTTP Request: POST https://huggingface.co/api/repos/create "HTTP/1.1 409 Conflict"
# INFO 2026-03-09 02:52:16 _client.py:1025 HTTP Request: POST https://huggingface.co/api/models/lmerkle/hf_act_recordpolicy10/preupload/main "HTTP/1.1 200 OK"
# INFO 2026-03-09 02:52:16 _client.py:1025 HTTP Request: POST https://huggingface.co/lmerkle/hf_act_recordpolicy10.git/info/lfs/objects/batch "HTTP/1.1 200 OK"
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100% 6.56k/6.56k [00:00<?, ?B/s]
#
# Processing Files (1 / 1)      : 100% 6.56k/6.56k [00:00<00:00, 44.6kB/s,   ???B/s  ]
#
# Processing Files (1 / 1)      : 100% 6.56k/6.56k [00:00<00:00, 32.3kB/s,  0.00B/s  ]
# New Data Upload               : |          |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100% 6.56k/6.56k [00:00<?, ?B/s]
# INFO 2026-03-09 02:52:17 _client.py:1025 HTTP Request: POST https://huggingface.co/api/models/lmerkle/hf_act_recordpolicy10/commit/main "HTTP/1.1 200 OK"
# INFO 2026-03-09 02:52:18 _client.py:1025 HTTP Request: POST https://huggingface.co/api/repos/create "HTTP/1.1 409 Conflict"
# INFO 2026-03-09 02:52:18 _client.py:1025 HTTP Request: POST https://huggingface.co/api/models/lmerkle/hf_act_recordpolicy10/preupload/main "HTTP/1.1 200 OK"
# INFO 2026-03-09 02:52:18 _client.py:1025 HTTP Request: POST https://huggingface.co/lmerkle/hf_act_recordpolicy10.git/info/lfs/objects/batch "HTTP/1.1 200 OK"
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100% 6.56k/6.56k [00:00<?, ?B/s]
#
# Processing Files (1 / 1)      : 100% 6.56k/6.56k [00:00<00:00, 48.5kB/s,   ???B/s  ]
#
# Processing Files (1 / 1)      : 100% 6.56k/6.56k [00:00<00:00, 32.5kB/s,  0.00B/s  ]
# New Data Upload               : |          |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100% 6.56k/6.56k [00:00<?, ?B/s]
# INFO 2026-03-09 02:52:19 _client.py:1025 HTTP Request: POST https://huggingface.co/api/models/lmerkle/hf_act_recordpolicy10/commit/main "HTTP/1.1 200 OK"

# %% [markdown]
# ## Login into Hugging Face Hub.
# ### Now after training is done login into the Hugging Face hub and upload the last checkpoint.

# %%
from huggingface_hub import HfApi

HF_USERNAME = "${HF_USER}"
HF_REPO_NAME = "act-configs"

api = HfApi()
repo_id = f"{HF_USERNAME}/{HF_REPO_NAME}"
files_in_repo = api.list_repo_files(repo_id=repo_id)

print(f"Files in {repo_id}:")
for file in files_in_repo:
    print(f"- {file}")

# %% [markdown]
# ### Configure Hugging Face Token
#
# Add your HF_TOKEN (AKA Secret) to Google Colab to enable Colab to access your HF repositories. This is optional and might need modification if you are using another cloud provider.

# %%
from google.colab import userdata
import os

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# Verify token is loaded (optional)
if os.getenv("HF_TOKEN"):
    print("Hugging Face token loaded successfully.")
else:
    print("Error: Hugging Face token not found. Please set it as a Colab secret named 'HF_TOKEN'.")

# %%
from google.colab import userdata
userdata.get('HF_TOKEN')

# %% [markdown]
# ### Download files from Hugging Face Hub into Colab
#
# Now, you can use `hf_hub_download` to pull the files directly to your Colab environment. You can then download them from Colab to your local machine. This is optional.

# %%
from huggingface_hub import hf_hub_download

# Your Hugging Face repository details
HF_CONFIG_REPO_ID = "${HF_USER}/act-configs" # Where train_config.json should be
HF_POLICY_REPO_ID = "${HF_USER}/hf_act_recordpolicy0" # Where the trained model is

# Define the files to download
config_file_name = "train_config.json"
model_file_name = "model.safetensors"
tokenizer_processor_file_name = "tokenizer_processor.safetensors"

# Download train_config.json
train_config_path = hf_hub_download(repo_id=HF_CONFIG_REPO_ID, filename=config_file_name)
print(f"Downloaded {config_file_name} to: {train_config_path}")

# Download the trained model files
model_path = hf_hub_download(repo_id=HF_POLICY_REPO_ID, filename=model_file_name)
print(f"Downloaded {model_file_name} to: {model_path}")

tokenizer_processor_path = hf_hub_download(repo_id=HF_POLICY_REPO_ID, filename=tokenizer_processor_file_name)
print(f"Downloaded {tokenizer_processor_file_name} to: {tokenizer_processor_path}")

print("\nAll specified files have been downloaded to your Colab environment.")
print("You can find them in the paths printed above. To download them to your local machine, right-click on the files in the Colab file browser (left sidebar) and select 'Download'.")

# %% [markdown]
# ### Verify `train_config.json` existence locally. This is needed for restarting training and testing of the policy.

# %%
# !ls -l /content/lerobot/outputs/train/hf_act_record0/

# %%
HF_USERNAME = "${HF_USER}"
HF_REPO_NAME = "act-configs"

# !hf repo-files $HF_USERNAME/$HF_REPO_NAME

# %%
# !hf auth login

# %%
# !hf upload ${HF_USER}/hf_act_record0 \
  /content/lerobot/outputs/train/hf_act_record0/checkpoints/last/pretrained_model

# %%
# !hf auth login

# %% [markdown]
# ### Create a new repository on Hugging Face Hub
#
# This command will create a new repository under your Hugging Face account.

# %%
HF_USERNAME = "${HF_USER}"
HF_REPO_NAME = "act-configs"

# !hf repo create $HF_REPO_NAME --type model --private --organization $HF_USERNAME

# %%
### Upload `train_config.json` to the new repository
HF_USERNAME = "${HF_USER}"
HF_REPO_NAME = "act-configs"
LOCAL_CONFIG_PATH = "/content/lerobot/outputs/train/hf_act_record0/train_config.json"

# !hf upload $HF_USERNAME/$HF_REPO_NAME "$LOCAL_CONFIG_PATH" train_config.json

# %%
from huggingface_hub import HfApi, notebook_login
import os

# 1. Log in (Only needs to be done once per session)
# If you already logged in, you can comment this out.
notebook_login()

# 2. Configuration - Update these to match your setup!
local_checkpoint_path = "./outputs/train/hf_act_record10/checkpoints/last"
repo_id = "lmerkle/charger"  # Your HF repo
commit_message = "Uploading latest ACT checkpoint from Colab"

# 3. Validation and Upload
api = HfApi()

if os.path.exists(local_checkpoint_path):
    print(f"🚀 Starting upload of {local_checkpoint_path} to {repo_id}...")

    api.upload_folder(
        folder_path=local_checkpoint_path,
        repo_id=repo_id,
        commit_message=commit_message,
        run_as_future=True # Set to False if you want to wait for it to finish
    )

    print(f"✅ Upload initiated! Check your repo at: https://huggingface.co/{repo_id}")
else:
    print("❌ Error: Checkpoint folder not found. Has the model saved its first 'save_freq' yet?")
# Out:
# ❌ Error: Checkpoint folder not found. Has the model saved its first 'save_freq' yet?
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
